# %% [markdown]
# <a href="https://colab.research.google.com/github/saubhagyav/COMPANY_BANKRUPTCY_PREDICTION/blob/main/Final_Saubhagya_company_bankruptcy_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Prediction of bankruptcy is a phenomenon of increasing interest to firms who
# stand to loose money because on unpaid debts. Since computers can store huge dataset
# pertaining to bankruptcy making accurate predictions from them before hand is becoming
# important.
#
# The data were collected from the Taiwan Economic Journal for the years 1999 to 2009. Company bankruptcy was defined based on the business regulations of the Taiwan Stock Exchange.
#
#  In this project you will use various classification algorithms on bankruptcy
# dataset to predict bankruptcies with satisfying accuracies long before the actual event.

# %% [markdown]
# # **Attribute Information**

# %% [markdown]
# Updated column names and description to make the data easier to understand (Y = Output feature, X = Input features)
#
# Y - Bankrupt?: Class label 1 : Yes , 0: No
#
# X1 - ROA(C) before interest and depreciation before interest: Return On Total Assets(C)
#
# X2 - ROA(A) before interest and % after tax: Return On Total Assets(A)
#
# X3 - ROA(B) before interest and depreciation after tax: Return On Total Assets(B)
#
# X4 - Operating Gross Margin: Gross Profit/Net Sales
#
# X5 - Realized Sales Gross Margin: Realized Gross Profit/Net Sales
#
# X6 - Operating Profit Rate: Operating Income/Net Sales
#
# X7 - Pre-tax net Interest Rate: Pre-Tax Income/Net Sales
#
# X8 - After-tax net Interest Rate: Net Income/Net Sales
#
# X9 - Non-industry income and expenditure/revenue: Net Non-operating Income Ratio
#
# X10 - Continuous interest rate (after tax): Net Income-Exclude Disposal Gain or Loss/Net Sales
#
# X11 - Operating Expense Rate: Operating Expenses/Net Sales
#
# X12 - Research and development expense rate: (Research and Development Expenses)/Net Sales
#
# X13 - Cash flow rate: Cash Flow from Operating/Current Liabilities
#
# X14 - Interest-bearing debt interest rate: Interest-bearing Debt/Equity
#
# X15 - Tax rate (A): Effective Tax Rate
#
# X16 - Net Value Per Share (B): Book Value Per Share(B)
#
# X17 - Net Value Per Share (A): Book Value Per Share(A)
#
# X18 - Net Value Per Share (C): Book Value Per Share(C)
#
# X19 - Persistent EPS in the Last Four Seasons: EPS-Net Income
#
# X20 - Cash Flow Per Share
#
# X21 - Revenue Per Share (Yuan ¥): Sales Per Share
#
# X22 - Operating Profit Per Share (Yuan ¥): Operating Income Per Share
#
# X23 - Per Share Net profit before tax (Yuan ¥): Pretax Income Per Share
#
# X24 - Realized Sales Gross Profit Growth Rate
#
# X25 - Operating Profit Growth Rate: Operating Income Growth
#
# X26 - After-tax Net Profit Growth Rate: Net Income Growth
#
# X27 - Regular Net Profit Growth Rate: Continuing Operating Income after Tax Growth
#
# X28 - Continuous Net Profit Growth Rate: Net Income-Excluding Disposal Gain or Loss Growth
#
# X29 - Total Asset Growth Rate: Total Asset Growth
#
# X30 - Net Value Growth Rate: Total Equity Growth
#
# X31 - Total Asset Return Growth Rate Ratio: Return on Total Asset Growth
#
# X32 - Cash Reinvestment %: Cash Reinvestment Ratio
#
# X33 - Current Ratio
#
# X34 - Quick Ratio: Acid Test
#
# X35 - Interest Expense Ratio: Interest Expenses/Total Revenue
#
# X36 - Total debt/Total net worth: Total Liability/Equity Ratio
#
# X37 - Debt ratio %: Liability/Total Assets
#
# X38 - Net worth/Assets: Equity/Total Assets
#
# X39 - Long-term fund suitability ratio (A): (Long-term Liability+Equity)/Fixed Assets
#
# X40 - Borrowing dependency: Cost of Interest-bearing Debt
#
# X41 - Contingent liabilities/Net worth: Contingent Liability/Equity
#
# X42 - Operating profit/Paid-in capital: Operating Income/Capital
#
# X43 - Net profit before tax/Paid-in capital: Pretax Income/Capital
#
# X44 - Inventory and accounts receivable/Net value: (Inventory+Accounts Receivables)/Equity
#
# X45 - Total Asset Turnover
#
# X46 - Accounts Receivable Turnover
#
# X47 - Average Collection Days: Days Receivable Outstanding
#
# X48 - Inventory Turnover Rate (times)
#
# X49 - Fixed Assets Turnover Frequency
#
# X50 - Net Worth Turnover Rate (times): Equity Turnover
#
# X51 - Revenue per person: Sales Per Employee
#
# X52 - Operating profit per person: Operation Income Per Employee
#
# X53 - Allocation rate per person: Fixed Assets Per Employee
#
# X54 - Working Capital to Total Assets
#
# X55 - Quick Assets/Total Assets
#
# X56 - Current Assets/Total Assets
#
# X57 - Cash/Total Assets
#
# X58 - Quick Assets/Current Liability
#
# X59 - Cash/Current Liability
#
# X60 - Current Liability to Assets
#
# X61 - Operating Funds to Liability
#
# X62 - Inventory/Working Capital
#
# X63 - Inventory/Current Liability
#
# X64 - Current Liabilities/Liability
#
# X65 - Working Capital/Equity
#
# X66 - Current Liabilities/Equity
#
# X67 - Long-term Liability to Current Assets
#
# X68 - Retained Earnings to Total Assets
#
# X69 - Total income/Total expense
#
# X70 - Total expense/Assets
#
# X71 - Current Asset Turnover Rate: Current Assets to Sales
#
# X72 - Quick Asset Turnover Rate: Quick Assets to Sales
#
# X73 - Working capitcal Turnover Rate: Working Capital to Sales
#
# X74 - Cash Turnover Rate: Cash to Sales
#
# X75 - Cash Flow to Sales
#
# X76 - Fixed Assets to Assets
#
# X77 - Current Liability to Liability
#
# X78 - Current Liability to Equity
#
# X79 - Equity to Long-term Liability
#
# X80 - Cash Flow to Total Assets
#
# X81 - Cash Flow to Liability
#
# X82 - CFO to Assets
#
# X83 - Cash Flow to Equity
#
# X84 - Current Liability to Current Assets
#
# X85 - Liability-Assets Flag: 1 if Total Liability exceeds Total Assets, 0 otherwise
#
# X86 - Net Income to Total Assets
#
# X87 - Total assets to GNP price
#
# X88 - No-credit Interval
#
# X89 - Gross Profit to Sales
#
# X90 - Net Income to Stockholder's Equity
#
# X91 - Liability to Equity
#
# X92 - Degree of Financial Leverage (DFL)
#
# X93 - Interest Coverage Ratio (Interest expense to EBIT)
#
# X94 - Net Income Flag: 1 if Net Income is Negative for the last two years, 0 otherwise
#
# X95 - Equity to Liability

# %% [markdown]
# # **Loading the Dataset into the Colab Notebook**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importing basic libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
path = '/content/drive/MyDrive/Alma Better/Capstone Projects/(SL)Company Bankruptcy Prediction/Copy of COMPANY BANKRUPTCY PREDICTION.csv'

# %%
# Loading the Dataset in the colab notebook.
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Bankrupt?  ...   Equity to Liability
# 0          1  ...              0.016469
# 1          1  ...              0.020794
# 2          1  ...              0.016474
# 3          1  ...              0.023982
# 4          1  ...              0.035490
#
# [5 rows x 96 columns]

# %% [markdown]
# ### Upon Initial glance at the columns, we can clearly observe that the dataset is already pretty clean and has already been standardized beforehand.

# %%
df.shape
# Out:
# (6819, 96)

# %% [markdown]
# # **Checking for Null Values in the Dataset:-**

# %%
df.isnull().any()
# Out:
# Bankrupt?                                                   False
#  ROA(C) before interest and depreciation before interest    False
#  ROA(A) before interest and % after tax                     False
#  ROA(B) before interest and depreciation after tax          False
#  Operating Gross Margin                                     False
#                                                             ...
#  Liability to Equity                                        False
#  Degree of Financial Leverage (DFL)                         False
#  Interest Coverage Ratio (Interest expense to EBIT)         False
#  Net Income Flag                                            False
#  Equity to Liability                                        False
# Length: 96, dtype: bool

# %%
null_df = df.isnull().sum().reset_index()
null_df.rename(columns={'index':'feature_name', 0:'number_of_null_values'})
# Out:
#                                          feature_name  number_of_null_values
# 0                                           Bankrupt?                      0
# 1    ROA(C) before interest and depreciation befor...                      0
# 2              ROA(A) before interest and % after tax                      0
# 3    ROA(B) before interest and depreciation after...                      0
# 4                              Operating Gross Margin                      0
# ..                                                ...                    ...
# 91                                Liability to Equity                      0
# 92                 Degree of Financial Leverage (DFL)                      0
# 93   Interest Coverage Ratio (Interest expense to ...                      0
# 94                                    Net Income Flag                      0
# 95                                Equity to Liability                      0
#
# [96 rows x 2 columns]

# %% [markdown]
# ### We can observe that the dataset doesn't contain any null values.

# %% [markdown]
# # **Visualizing the Target Variable in the Dataset:-**

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
sns.countplot(df['Bankrupt?'])

# %% [markdown]
# ### So the dataset looks quite imbalanced between normal companies and bankrupt companies.

# %%
#Determine the number of fraud and valid transactions in the dataset

Fraud = df[df['Bankrupt?']==1]

Valid = df[df['Bankrupt?']==0]

outlier_percentage = len(Fraud)*100/float(len(Valid))

# %%
print("Percentage of Bankruptcy cases in our dataset : {}".format(outlier_percentage))

print("Bankruptcy cases : {}".format(len(Fraud)))

print("Normal Cases : {}".format(len(Valid)))
# Out:
# Percentage of Bankruptcy cases in our dataset : 3.333838460372784
# Bankruptcy cases : 220
# Normal Cases : 6599

# %% [markdown]
# ### Overall, we have 3.33% Bankruptcy cases for companies in our Dataset.

# %% [markdown]
# # **Hypothesis 1:- We assume that the Categorical Variables are not a good indicator for detecting bankruptcy in companies.**

# %%
df[' Net Income Flag'].value_counts()
# Out:
# 1    6819
# Name:  Net Income Flag, dtype: int64

# %%
sns.countplot(df[' Net Income Flag'])

# %%
df[' Liability-Assets Flag'].value_counts()
# Out:
# 0    6811
# 1       8
# Name:  Liability-Assets Flag, dtype: int64

# %%
sns.countplot(df[' Liability-Assets Flag'])

# %%
df[(df[' Liability-Assets Flag']==1) & (df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...   Equity to Liability
# 56            1  ...              0.009178
# 1869          1  ...              0.009879
# 1870          1  ...              0.008950
# 2001          1  ...              0.008753
# 2470          1  ...              0.008500
# 6640          1  ...              0.003946
#
# [6 rows x 96 columns]

# %% [markdown]
# ### Since the above two columns do not provide much relavance to capture bankrupt companies, our hypothesis was correct. Therefore, we remove these two categorical features.

# %%
df.drop(columns=[' Net Income Flag',' Liability-Assets Flag'], inplace=True)

# %% [markdown]
# ### Now we are left with 94 columns in total.

# %%
df.shape
# Out:
# (6819, 94)

# %% [markdown]
# # **Sorting Independent and Dependent Variables in our Dataset:-**

# %%
df2 = df.drop(columns=['Bankrupt?']).copy()
df2.head(2)
# Out:
#     ROA(C) before interest and depreciation before interest  ...   Equity to Liability
# 0                                           0.370594         ...              0.016469
# 1                                           0.464291         ...              0.020794
#
# [2 rows x 93 columns]

# %%
X = df2
Y = df['Bankrupt?'].map({0:1,1:-1})

# %% [markdown]
# # **Basic EDA of the Dataset:-**

# %%
list_of_columns = df2.columns.tolist()

# %%
for i in list_of_columns:
  sns.displot(data=df2, x=i, kind='kde')

# %% [markdown]
# ## **Observations:-**
# 1. The data has many outliers and it can be seen that it is very skewed.
# 2. Many columns are highly skewed, both in left and right direction.
# 3. We found that a lot of columns have high kurtosis.

# %% [markdown]
# ## **Now Checking for Correlation in the data:-**

# %%
correlation = df.corr(method='pearson')
correlation_with_respect_to_target_variable = correlation.head(1)
correlation_with_respect_to_target_variable
# Out:
#            Bankrupt?  ...   Equity to Liability
# Bankrupt?        1.0  ...             -0.083048
#
# [1 rows x 94 columns]

# %% [markdown]
# ## Now let us Visualize all the correlated columns in the dataset:-

# %%
plt.figure(figsize=(30,5))
sns.heatmap(correlation_with_respect_to_target_variable.iloc[:,0:20], annot=True)

# %%
plt.figure(figsize=(30,5))
sns.heatmap(correlation_with_respect_to_target_variable.iloc[:,20:40], annot=True)

# %%
plt.figure(figsize=(30,5))
sns.heatmap(correlation_with_respect_to_target_variable.iloc[:,40:60], annot=True)

# %%
plt.figure(figsize=(30,5))
sns.heatmap(correlation_with_respect_to_target_variable.iloc[:,60:80], annot=True)

# %%
plt.figure(figsize=(30,5))
sns.heatmap(correlation_with_respect_to_target_variable.iloc[:,80:], annot=True)

# %% [markdown]
# ### After going through all the columns we found that none of the features displayed any high correlation(> 0.5) with the target variable bankruptcy.
# ### 1. The most negatively correlated feature was ' Net-Income to Total Assets' i.e -0.32**
# ### 2.The most positively correlated feature was ' Debt Ratio' i.e +0.25.
#
# ## **Conclusion**: Our dataset doesn't provide any modelling power with respect to linear algorithms.

# %% [markdown]
# # **Hypothesis 2: Since the Target Variable has only 3% bankruptcy cases, I assume that bankruptcy is an anomaly and we will be able to predict it using unsupervised anomaly detection models.**

# %% [markdown]
# # **Converting Dataset using StandardScalar:-**

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X_1 = st.fit_transform(X)
X_1
# Out:
# array([[-2.21790935e+00, -2.04579778e+00, -2.40036100e+00, ...,
#         -6.00307071e-02, -9.89778602e-02, -6.22067292e-01],
#        [-6.73828192e-01, -3.11067861e-01, -5.98449692e-01, ...,
#          1.51298163e+01,  3.64558703e-01, -5.35573366e-01],
#        [-1.30367191e+00, -9.08419781e-01, -1.31990960e+00, ...,
#         -6.29611627e-02, -1.25015000e-01, -6.21959845e-01],
#        ...,
#        [-5.34844821e-01, -3.79194227e-01, -5.34995989e-01, ...,
#         -4.78695755e-02, -1.51013169e-02,  1.00120640e+00],
#        [ 1.78751762e-02,  1.95942589e-02,  7.40278540e-03, ...,
#         -4.58978268e-02, -4.27044097e-03, -7.13638449e-02],
#        [-1.99838660e-01,  1.74955607e-01, -6.56124342e-02, ...,
#         -4.77549464e-02, -1.44543493e-02,  3.72572884e+00]])

# %% [markdown]
# # **Train and Test Split of the Dataset:-**

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_Y,test_Y = train_test_split(X_1,Y,test_size=0.25, random_state=0, stratify=Y)

# %%
train_X.shape, test_X.shape
# Out:
# ((5114, 93), (1705, 93))

# %%
train_Y.shape, test_Y.shape
# Out:
# ((5114,), (1705,))

# %%
test_Y.value_counts()
# Out:
#  1    1650
# -1      55
# Name: Bankrupt?, dtype: int64

# %%
train_Y.value_counts()
# Out:
#  1    4949
# -1     165
# Name: Bankrupt?, dtype: int64

# %% [markdown]
# # **Forming Anomaly Detection Models to capture the bankruptcy cases in the Dataset:-**

# %% [markdown]
# ## **Building Isolation Forest Model in UnSupervised Setting:-**

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %%
clf=IsolationForest(n_estimators=100, max_samples='auto', \
                        max_features=1.0, bootstrap=False, n_jobs=-1, random_state=0, verbose=0, contamination=0.033)
clf.fit(train_X)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=0.033,
#                 max_features=1.0, max_samples='auto', n_estimators=100,
#                 n_jobs=-1, random_state=0, verbose=0, warm_start=False)

# %%
pred_train = clf.predict(train_X)
np.unique(pred_train, return_counts=True)
# Out:
# (array([-1,  1]), array([ 169, 4945]))

# %%
target_names = ['bankrupt_company', 'normal_company']
print(classification_report(train_Y, pred_train, target_names=target_names))
print ("AUC: ", "{:.1%}".format(roc_auc_score(train_Y, pred_train)))
cm = confusion_matrix(train_Y, pred_train )
print(cm)
# Out:
#                   precision    recall  f1-score   support
#
# bankrupt_company       0.16      0.16      0.16       165
#   normal_company       0.97      0.97      0.97      4949
#
#         accuracy                           0.95      5114
#        macro avg       0.57      0.57      0.57      5114
#     weighted avg       0.95      0.95      0.95      5114
#
# AUC:  56.7%
# [[  27  138]
#  [ 142 4807]]

# %%
pred_test = clf.predict(test_X)
np.unique(pred_test, return_counts=True)
# Out:
# (array([-1,  1]), array([  66, 1639]))

# %%
target_names2 = ['bankrupt_company', 'normal_company']
print(classification_report(test_Y, pred_test, target_names=target_names2))
print ("AUC: ", "{:.1%}".format(roc_auc_score(test_Y, pred_test)))
cm2 = confusion_matrix(test_Y, pred_test)
print(cm2)
# Out:
#                   precision    recall  f1-score   support
#
# bankrupt_company       0.27      0.33      0.30        55
#   normal_company       0.98      0.97      0.97      1650
#
#         accuracy                           0.95      1705
#        macro avg       0.63      0.65      0.64      1705
#     weighted avg       0.95      0.95      0.95      1705
#
# AUC:  64.9%
# [[  18   37]
#  [  48 1602]]

# %% [markdown]
# ### In Isolation Forest, we are able to get close to 64% AUC score along with 33% recall on test set which is not bad considering the level of imbalance in the dataset.

# %% [markdown]
# ## **Building Local Outlier Factor Model in UnSupervised Setting:-**

# %%
from sklearn.neighbors import LocalOutlierFactor

# %%
clf2 = LocalOutlierFactor(n_neighbors=35, contamination=0.03, novelty=False)
clf2.fit(train_X)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.03, leaf_size=30,
#                    metric='minkowski', metric_params=None, n_jobs=None,
#                    n_neighbors=35, novelty=False, p=2)

# %%
pred_train2 = clf2.fit_predict(train_X)
np.unique(pred_train2, return_counts=True)
# Out:
# (array([-1,  1]), array([ 154, 4960]))

# %%
target_names = ['bankrupt_company', 'normal_company']
print(classification_report(train_Y, pred_train2, target_names=target_names))
print ("AUC: ", "{:.1%}".format(roc_auc_score(train_Y, pred_train2)))
cm_lof = confusion_matrix(train_Y, pred_train2 )
print(cm_lof)
# Out:
#                   precision    recall  f1-score   support
#
# bankrupt_company       0.12      0.12      0.12       165
#   normal_company       0.97      0.97      0.97      4949
#
#         accuracy                           0.95      5114
#        macro avg       0.55      0.54      0.55      5114
#     weighted avg       0.94      0.95      0.94      5114
#
# AUC:  54.4%
# [[  19  146]
#  [ 135 4814]]

# %%
pred_test2 = clf.fit_predict(test_X)
np.unique(pred_test2, return_counts=True)
# Out:
# (array([-1,  1]), array([  57, 1648]))

# %%
target_names = ['bankrupt_company', 'normal_company']
print(classification_report(test_Y, pred_test2, target_names=target_names))
print ("AUC: ", "{:.1%}".format(roc_auc_score(test_Y, pred_test2)))
cm2 = confusion_matrix(test_Y, pred_test2)
print(cm2)
# Out:
#                   precision    recall  f1-score   support
#
# bankrupt_company       0.28      0.29      0.29        55
#   normal_company       0.98      0.98      0.98      1650
#
#         accuracy                           0.95      1705
#        macro avg       0.63      0.63      0.63      1705
#     weighted avg       0.95      0.95      0.95      1705
#
# AUC:  63.3%
# [[  16   39]
#  [  41 1609]]

# %% [markdown]
# ### In Local Outlier Factor model, we are able to get close to 63.3% AUC score along with 29% recall on test set which is slightly less than the isolation forest predictions.

# %% [markdown]
# ## **Running Isolation Forest Using KBest Features:-**

# %%
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import SelectKBest

# %%
transformer2 = SelectKBest(f_classif, k=18)
X_K15 = transformer2.fit_transform(X, Y)

# %%
best = X_K15[0].tolist()
df.iloc[0,1] in best
list_of_best_estimators = []
for index,name in enumerate(df.columns):
  if df.iloc[0,index] in best:
    list_of_best_estimators.append(name) 

list_of_best_estimators
# Out:
# [' ROA(C) before interest and depreciation before interest',
#  ' ROA(A) before interest and % after tax',
#  ' ROA(B) before interest and depreciation after tax',
#  ' Net Value Per Share (B)',
#  ' Net Value Per Share (A)',
#  ' Net Value Per Share (C)',
#  ' Persistent EPS in the Last Four Seasons',
#  ' Per Share Net profit before tax (Yuan ¥)',
#  ' Debt ratio %',
#  ' Net worth/Assets',
#  ' Borrowing dependency',
#  ' Net profit before tax/Paid-in capital',
#  ' Working Capital to Total Assets',
#  ' Current Liability to Assets',
#  ' Retained Earnings to Total Assets',
#  ' Current Liability to Current Assets',
#  ' Net Income to Total Assets',
#  " Net Income to Stockholder's Equity",
#  ' Liability to Equity']

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_Y,test_Y = train_test_split(X_K15,Y,test_size=0.25, random_state=0, stratify=Y)

# %%
train_X.shape, test_X.shape
# Out:
# ((5114, 18), (1705, 18))

# %%
train_Y.shape, test_Y.shape
# Out:
# ((5114,), (1705,))

# %%
test_Y.value_counts()
# Out:
#  1    1650
# -1      55
# Name: Bankrupt?, dtype: int64

# %%
train_Y.value_counts()
# Out:
#  1    4949
# -1     165
# Name: Bankrupt?, dtype: int64

# %%
clf=IsolationForest(n_estimators=100, max_samples='auto', \
                        max_features=1.0, bootstrap=True, n_jobs=-1, random_state=0, verbose=0, contamination=0.033)
clf.fit(train_X)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=True, contamination=0.033,
#                 max_features=1.0, max_samples='auto', n_estimators=100,
#                 n_jobs=-1, random_state=0, verbose=0, warm_start=False)

# %%
pred_train = clf.predict(train_X)
np.unique(pred_train, return_counts=True)
# Out:
# (array([-1,  1]), array([ 169, 4945]))

# %%
print(classification_report(train_Y, pred_train))
print ("AUC: ", "{:.1%}".format(roc_auc_score(train_Y, pred_train)))
cm = confusion_matrix(train_Y, pred_train)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.23      0.24      0.23       165
#            1       0.97      0.97      0.97      4949
#
#     accuracy                           0.95      5114
#    macro avg       0.60      0.61      0.60      5114
# weighted avg       0.95      0.95      0.95      5114
#
# AUC:  60.5%
# [[  39  126]
#  [ 130 4819]]

# %%
pred_test = clf.predict(test_X)
np.unique(pred_test, return_counts=True)
# Out:
# (array([-1,  1]), array([  71, 1634]))

# %%
print(classification_report(test_Y, pred_test))
print ("AUC: ", "{:.1%}".format(roc_auc_score(test_Y, pred_test)))
cm2 = confusion_matrix(test_Y, pred_test)
print(cm2)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.34      0.44      0.38        55
#            1       0.98      0.97      0.98      1650
#
#     accuracy                           0.95      1705
#    macro avg       0.66      0.70      0.68      1705
# weighted avg       0.96      0.95      0.96      1705
#
# AUC:  70.4%
# [[  24   31]
#  [  47 1603]]

# %% [markdown]
# # **Running Local Outlier Factor Using KBest Features:-**

# %%
train_X.shape, test_X.shape
# Out:
# ((5114, 18), (1705, 18))

# %%
clf2 = LocalOutlierFactor(n_neighbors=35, contamination=0.03, novelty=False)
clf2.fit(train_X)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.03, leaf_size=30,
#                    metric='minkowski', metric_params=None, n_jobs=None,
#                    n_neighbors=35, novelty=False, p=2)

# %%
pred_train2 = clf2.fit_predict(train_X)
np.unique(pred_train2, return_counts=True)
# Out:
# (array([-1,  1]), array([ 154, 4960]))

# %%
target_names = ['bankrupt_company', 'normal_company']
print(classification_report(train_Y, pred_train2, target_names=target_names))
print ("AUC: ", "{:.1%}".format(roc_auc_score(train_Y, pred_train2)))
cm_lof = confusion_matrix(train_Y, pred_train2 )
print(cm_lof)
# Out:
#                   precision    recall  f1-score   support
#
# bankrupt_company       0.13      0.12      0.13       165
#   normal_company       0.97      0.97      0.97      4949
#
#         accuracy                           0.95      5114
#        macro avg       0.55      0.55      0.55      5114
#     weighted avg       0.94      0.95      0.94      5114
#
# AUC:  54.7%
# [[  20  145]
#  [ 134 4815]]

# %%
pred_test2 = clf.fit_predict(test_X)
np.unique(pred_test2, return_counts=True)
# Out:
# (array([-1,  1]), array([  57, 1648]))

# %%
target_names = ['bankrupt_company', 'normal_company']
print(classification_report(test_Y, pred_test2, target_names=target_names))
print ("AUC: ", "{:.1%}".format(roc_auc_score(test_Y, pred_test2)))
cm2 = confusion_matrix(test_Y, pred_test2)
print(cm2)
# Out:
#                   precision    recall  f1-score   support
#
# bankrupt_company       0.28      0.29      0.29        55
#   normal_company       0.98      0.98      0.98      1650
#
#         accuracy                           0.95      1705
#        macro avg       0.63      0.63      0.63      1705
#     weighted avg       0.95      0.95      0.95      1705
#
# AUC:  63.3%
# [[  16   39]
#  [  41 1609]]

# %% [markdown]
# ### Still we are not able to get much recall and precision values even after choosing 18 KBest Features in the above models.

# %% [markdown]
# ## **Conclusion:-**  Our initial Assumption that this is an anomaly detection problem is not correct. Let us use PCA for visualizing our datasets to gain more information on the nature of target variable.

# %% [markdown]
# # **Visualizing the Target Variable Values using PCA:-**

# %%
bankrupt_index = df[df['Bankrupt?']==1].index 
bankrupt_index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,   29,   30,   54,   55,
#             ...
#             6454, 6498, 6499, 6500, 6545, 6591, 6640, 6641, 6642, 6728],
#            dtype='int64', length=220)

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
pca.fit(X)

res=pd.DataFrame(pca.transform(X))

Z = np.array(res)
figsize=(12, 7)
plt.figure(figsize=figsize)
plt.title("IsolationForest")
plt.contourf( Z, cmap=plt.cm.Blues_r)

b1 = plt.scatter(res[0], res[1], c='blue',
                 s=40,label="normal points")

b1 = plt.scatter(res.iloc[bankrupt_index,0],res.iloc[bankrupt_index,1], c='red',
                 s=40,  edgecolor="red",label="Actual outliers")
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
pca = PCA(n_components=3)  # Reduce to k=3 dimensions
scaler = StandardScaler()
#normalize the metrics
X_s = scaler.fit_transform(X)
X_reduce = pca.fit_transform(X_s)

fig = plt.figure( figsize=(20,16))
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel("x_composite_3")

# Plot the compressed data points
ax.scatter(X_reduce[:, 0], X_reduce[:, 1], zs=X_reduce[:, 2], s=4, lw=1, label="inliers",c="blue")

# Plot x's for the ground truth outliers
ax.scatter(X_reduce[bankrupt_index,0],X_reduce[bankrupt_index,1], X_reduce[bankrupt_index,2],
           lw=2, s=60, marker="x", c="red", label="outliers")
ax.legend()
plt.show()

# %% [markdown]
# ### Based upon the observation, we can clearly say that this isn't an anomaly detection problem as their is a lot of data overlap between normal companies and bankrupt companies. This is probably the reason why I wasn't able to get good scores in my anomaly detection models.

# %% [markdown]
# # **We can also reduce the number of features by applying feature selection techniques as shown below:-**

# %% [markdown]
# ## **Different Techniques for Doing Feature Selection:-**

# %% [markdown]
# ## 1. Using p_values derived from OLS

# %%
#scaling the data
scaler=StandardScaler()
X_2=scaler.fit_transform(X)

# %%
import statsmodels.api as sm
model = sm.OLS(Y, X_2)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:              Bankrupt?   R-squared (uncentered):                   0.269
# Model:                            OLS   Adj. R-squared (uncentered):              0.259
# Method:                 Least Squares   F-statistic:                              27.53
# Date:                Sun, 05 Sep 2021   Prob (F-statistic):                        0.00
# Time:                        03:00:16   Log-Likelihood:                         -8606.7
# No. Observations:                6819   AIC:                                  1.739e+04
# Df Residuals:                    6729   BIC:                                  1.801e+04
# Df Model:                          90
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
p_val_ols= pd.DataFrame(zip(X.columns,results.pvalues),columns=['column','p_values'])
p_val_ols.head(5)
# Out:
#                                               column  p_values
# 0   ROA(C) before interest and depreciation befor...  0.002221
# 1             ROA(A) before interest and % after tax  0.007631
# 2   ROA(B) before interest and depreciation after...  0.004103
# 3                             Operating Gross Margin  0.614783
# 4                        Realized Sales Gross Margin  0.397830

# %% [markdown]
# ### **Segregating Features based on 95% confidence interval:-**

# %%
# now let us choose the features which provide us 95% confidence (p-value<0.05)
columns_based_on_p_values_ols=[x for x in p_val_ols[p_val_ols.p_values<=0.05]['column']]
len(columns_based_on_p_values_ols)
# Out:
# 19

# %%
columns_based_on_p_values_ols
# Out:
# [' ROA(C) before interest and depreciation before interest',
#  ' ROA(A) before interest and % after tax',
#  ' ROA(B) before interest and depreciation after tax',
#  ' Tax rate (A)',
#  ' Net Value Per Share (A)',
#  ' Net Value Per Share (C)',
#  ' Continuous Net Profit Growth Rate',
#  ' Debt ratio %',
#  ' Net worth/Assets',
#  ' Inventory/Working Capital',
#  ' Current Liabilities/Liability',
#  ' Current Liabilities/Equity',
#  ' Retained Earnings to Total Assets',
#  ' Total expense/Assets',
#  ' Cash Turnover Rate',
#  ' Current Liability to Liability',
#  ' Current Liability to Equity',
#  ' Net Income to Total Assets',
#  " Net Income to Stockholder's Equity"]

# %% [markdown]
# ### **We reduced our columns to 19 from 94 using p_vlaues of OLS model.**

# %% [markdown]
# ## 2. Using Lasso Regression for finding Optimum Features:-
