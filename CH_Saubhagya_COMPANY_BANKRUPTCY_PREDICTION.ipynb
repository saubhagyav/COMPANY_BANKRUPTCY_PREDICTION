# %% [markdown]
# <a href="https://colab.research.google.com/github/saubhagyav/COMPANY_BANKRUPTCY_PREDICTION/blob/main/CH_Saubhagya_COMPANY_BANKRUPTCY_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Prediction of bankruptcy is a phenomenon of increasing interest to firms who
# stand to loose money because on unpaid debts. Since computers can store huge dataset
# pertaining to bankruptcy making accurate predictions from them before hand is becoming
# important.
#
# The data were collected from the Taiwan Economic Journal for the years 1999 to 2009. Company bankruptcy was defined based on the business regulations of the Taiwan Stock Exchange.
#
#  In this project you will use various classification algorithms on bankruptcy
# dataset to predict bankruptcies with satisfying accuracies long before the actual event.

# %% [markdown]
# # **Attribute Information**

# %% [markdown]
# Updated column names and description to make the data easier to understand (Y = Output feature, X = Input features)
#
# Y - Bankrupt?: Class label 1 : Yes , 0: No
#
# X1 - ROA(C) before interest and depreciation before interest: Return On Total Assets(C)
#
# X2 - ROA(A) before interest and % after tax: Return On Total Assets(A)
#
# X3 - ROA(B) before interest and depreciation after tax: Return On Total Assets(B)
#
# X4 - Operating Gross Margin: Gross Profit/Net Sales
#
# X5 - Realized Sales Gross Margin: Realized Gross Profit/Net Sales
#
# X6 - Operating Profit Rate: Operating Income/Net Sales
#
# X7 - Pre-tax net Interest Rate: Pre-Tax Income/Net Sales
#
# X8 - After-tax net Interest Rate: Net Income/Net Sales
#
# X9 - Non-industry income and expenditure/revenue: Net Non-operating Income Ratio
#
# X10 - Continuous interest rate (after tax): Net Income-Exclude Disposal Gain or Loss/Net Sales
#
# X11 - Operating Expense Rate: Operating Expenses/Net Sales
#
# X12 - Research and development expense rate: (Research and Development Expenses)/Net Sales
#
# X13 - Cash flow rate: Cash Flow from Operating/Current Liabilities
#
# X14 - Interest-bearing debt interest rate: Interest-bearing Debt/Equity
#
# X15 - Tax rate (A): Effective Tax Rate
#
# X16 - Net Value Per Share (B): Book Value Per Share(B)
#
# X17 - Net Value Per Share (A): Book Value Per Share(A)
#
# X18 - Net Value Per Share (C): Book Value Per Share(C)
#
# X19 - Persistent EPS in the Last Four Seasons: EPS-Net Income
#
# X20 - Cash Flow Per Share
#
# X21 - Revenue Per Share (Yuan ¥): Sales Per Share
#
# X22 - Operating Profit Per Share (Yuan ¥): Operating Income Per Share
#
# X23 - Per Share Net profit before tax (Yuan ¥): Pretax Income Per Share
#
# X24 - Realized Sales Gross Profit Growth Rate
#
# X25 - Operating Profit Growth Rate: Operating Income Growth
#
# X26 - After-tax Net Profit Growth Rate: Net Income Growth
#
# X27 - Regular Net Profit Growth Rate: Continuing Operating Income after Tax Growth
#
# X28 - Continuous Net Profit Growth Rate: Net Income-Excluding Disposal Gain or Loss Growth
#
# X29 - Total Asset Growth Rate: Total Asset Growth
#
# X30 - Net Value Growth Rate: Total Equity Growth
#
# X31 - Total Asset Return Growth Rate Ratio: Return on Total Asset Growth
#
# X32 - Cash Reinvestment %: Cash Reinvestment Ratio
#
# X33 - Current Ratio
#
# X34 - Quick Ratio: Acid Test
#
# X35 - Interest Expense Ratio: Interest Expenses/Total Revenue
#
# X36 - Total debt/Total net worth: Total Liability/Equity Ratio
#
# X37 - Debt ratio %: Liability/Total Assets
#
# X38 - Net worth/Assets: Equity/Total Assets
#
# X39 - Long-term fund suitability ratio (A): (Long-term Liability+Equity)/Fixed Assets
#
# X40 - Borrowing dependency: Cost of Interest-bearing Debt
#
# X41 - Contingent liabilities/Net worth: Contingent Liability/Equity
#
# X42 - Operating profit/Paid-in capital: Operating Income/Capital
#
# X43 - Net profit before tax/Paid-in capital: Pretax Income/Capital
#
# X44 - Inventory and accounts receivable/Net value: (Inventory+Accounts Receivables)/Equity
#
# X45 - Total Asset Turnover
#
# X46 - Accounts Receivable Turnover
#
# X47 - Average Collection Days: Days Receivable Outstanding
#
# X48 - Inventory Turnover Rate (times)
#
# X49 - Fixed Assets Turnover Frequency
#
# X50 - Net Worth Turnover Rate (times): Equity Turnover
#
# X51 - Revenue per person: Sales Per Employee
#
# X52 - Operating profit per person: Operation Income Per Employee
#
# X53 - Allocation rate per person: Fixed Assets Per Employee
#
# X54 - Working Capital to Total Assets
#
# X55 - Quick Assets/Total Assets
#
# X56 - Current Assets/Total Assets
#
# X57 - Cash/Total Assets
#
# X58 - Quick Assets/Current Liability
#
# X59 - Cash/Current Liability
#
# X60 - Current Liability to Assets
#
# X61 - Operating Funds to Liability
#
# X62 - Inventory/Working Capital
#
# X63 - Inventory/Current Liability
#
# X64 - Current Liabilities/Liability
#
# X65 - Working Capital/Equity
#
# X66 - Current Liabilities/Equity
#
# X67 - Long-term Liability to Current Assets
#
# X68 - Retained Earnings to Total Assets
#
# X69 - Total income/Total expense
#
# X70 - Total expense/Assets
#
# X71 - Current Asset Turnover Rate: Current Assets to Sales
#
# X72 - Quick Asset Turnover Rate: Quick Assets to Sales
#
# X73 - Working capitcal Turnover Rate: Working Capital to Sales
#
# X74 - Cash Turnover Rate: Cash to Sales
#
# X75 - Cash Flow to Sales
#
# X76 - Fixed Assets to Assets
#
# X77 - Current Liability to Liability
#
# X78 - Current Liability to Equity
#
# X79 - Equity to Long-term Liability
#
# X80 - Cash Flow to Total Assets
#
# X81 - Cash Flow to Liability
#
# X82 - CFO to Assets
#
# X83 - Cash Flow to Equity
#
# X84 - Current Liability to Current Assets
#
# X85 - Liability-Assets Flag: 1 if Total Liability exceeds Total Assets, 0 otherwise
#
# X86 - Net Income to Total Assets
#
# X87 - Total assets to GNP price
#
# X88 - No-credit Interval
#
# X89 - Gross Profit to Sales
#
# X90 - Net Income to Stockholder's Equity
#
# X91 - Liability to Equity
#
# X92 - Degree of Financial Leverage (DFL)
#
# X93 - Interest Coverage Ratio (Interest expense to EBIT)
#
# X94 - Net Income Flag: 1 if Net Income is Negative for the last two years, 0 otherwise
#
# X95 - Equity to Liability

# %% [markdown]
# # **Loading the Dataset into the Colab Notebook**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importing basic libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = '/content/drive/MyDrive/Alma Better/Capstone Projects/(SL)Company Bankruptcy Prediction/Copy of COMPANY BANKRUPTCY PREDICTION.csv'

# %%
# Loading the Dataset in the colab notebook.
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Bankrupt?  ...   Equity to Liability
# 0          1  ...              0.016469
# 1          1  ...              0.020794
# 2          1  ...              0.016474
# 3          1  ...              0.023982
# 4          1  ...              0.035490
#
# [5 rows x 96 columns]

# %%
df.shape
# Out:
# (6819, 96)

# %%
df.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %% [markdown]
# # **Visualizing the Target Variable in the Dataset:-**

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
sns.countplot(df['Bankrupt?'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # So the dataset looks quite imbalanced between normal companies and bankrupt companies.

# %% [markdown]
# # **Redundant Categorical Columns in the Dataset:-**

# %%
df[' Net Income Flag'].value_counts()
# Out:
# 1    6819
# Name:  Net Income Flag, dtype: int64

# %%
df[' Liability-Assets Flag'].value_counts()
# Out:
# 0    6811
# 1       8
# Name:  Liability-Assets Flag, dtype: int64

# %%
metrics_df[(df[' Liability-Assets Flag']==1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...   Equity to Liability
# 56            1  ...              0.009178
# 1869          1  ...              0.009879
# 1870          1  ...              0.008950
# 2001          1  ...              0.008753
# 2470          1  ...              0.008500
# 6640          1  ...              0.003946
#
# [6 rows x 96 columns]

# %%
df.drop(columns=[' Net Income Flag',' Liability-Assets Flag'], inplace=True)

# %% [markdown]
# # Upon Initial glance at the columns, we can clearly observe that the dataset is already pretty clean and has already been standardized beforehand.

# %% [markdown]
# # **Checking the columns for any potencial null values in it using .isnull() Function.**

# %%
null_df = df.isnull().sum().reset_index()

# %%
null_df.rename(columns={'index':'feature_name', 0:'number_of_null_values'})
# Out:
#                                          feature_name  number_of_null_values
# 0                                           Bankrupt?                      0
# 1    ROA(C) before interest and depreciation befor...                      0
# 2              ROA(A) before interest and % after tax                      0
# 3    ROA(B) before interest and depreciation after...                      0
# 4                              Operating Gross Margin                      0
# ..                                                ...                    ...
# 89                 Net Income to Stockholder's Equity                      0
# 90                                Liability to Equity                      0
# 91                 Degree of Financial Leverage (DFL)                      0
# 92   Interest Coverage Ratio (Interest expense to ...                      0
# 93                                Equity to Liability                      0
#
# [94 rows x 2 columns]

# %%
# Missing Value Count Function
def show_missing():
    missing = df.columns[df.isnull().any()].tolist()
    return missing

# Missing data counts and percentage
print('Missing Data Count')
print(df[show_missing()].isnull().sum().sort_values(ascending = False))
print('--'*50)
print('Missing Data Percentage')
print(round(df[show_missing()].isnull().sum().sort_values(ascending = False)/len(df)*100,2))
# Out:
# Missing Data Count
# Series([], dtype: float64)
# ----------------------------------------------------------------------------------------------------
# Missing Data Percentage
# Series([], dtype: float64)

# %%
df.describe()
# Out:
#          Bankrupt?  ...   Equity to Liability
# count  6819.000000  ...           6819.000000
# mean      0.032263  ...              0.047578
# std       0.176710  ...              0.050014
# min       0.000000  ...              0.000000
# 25%       0.000000  ...              0.024477
# 50%       0.000000  ...              0.033798
# 75%       0.000000  ...              0.052838
# max       1.000000  ...              1.000000
#
# [8 rows x 94 columns]

# %% [markdown]
# # **Now Checking for Correlation in the data:-**

# %%
df_slice1 = df.iloc[:,0:7]

# %%
correlation = df_slice1.corr(method='pearson')

# %%
correlation
# Out:
#                                                     Bankrupt?  ...   Operating Profit Rate
# Bankrupt?                                            1.000000  ...               -0.000230
#  ROA(C) before interest and depreciation before...  -0.260807  ...                0.035725
#  ROA(A) before interest and % after tax             -0.282941  ...                0.032053
#  ROA(B) before interest and depreciation after tax  -0.273051  ...                0.035212
#  Operating Gross Margin                             -0.100043  ...                0.005745
#  Realized Sales Gross Margin                        -0.099445  ...                0.005610
#  Operating Profit Rate                              -0.000230  ...                1.000000
#
# [7 rows x 7 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(correlation, annot=True)

# %% [markdown]
# # **Checking the level of skewness in the features of the Dataset:-**

# %%
from sklearn.preprocessing import PowerTransformer

# %%
tf = PowerTransformer()

# %%
transformed_df = pd.DataFrame(tf.fit_transform(df),columns=df.columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)

# %%
# Skewness 
df.skew().sort_values()
# Out:
#  Operating Profit Growth Rate           -71.688950
#  Operating Profit Rate                  -70.237164
#  Continuous interest rate (after tax)   -53.200121
#  After-tax net Interest Rate            -52.995744
#  Pre-tax net Interest Rate              -52.482867
#                                            ...
#  Contingent liabilities/Net worth        79.670620
#  Net Value Growth Rate                   80.291844
#  Total income/Total expense              82.332424
#  Current Ratio                           82.577237
#  Fixed Assets to Assets                  82.577237
# Length: 94, dtype: float64

# %%
transformed_df.skew().sort_values()
# Out:
#  Continuous Net Profit Growth Rate             -15.142657
#  Total Asset Return Growth Rate Ratio          -14.267057
#  Realized Sales Gross Profit Growth Rate        -7.879284
#  Inventory/Working Capital                      -7.470194
#  Non-industry income and expenditure/revenue    -7.236286
#                                                   ...
#  Cash Flow to Sales                             18.750241
#  Net Value Growth Rate                          19.058958
#  Pre-tax net Interest Rate                      21.519370
#  After-tax net Interest Rate                    21.587660
#  Continuous interest rate (after tax)           23.098449
# Length: 94, dtype: float64

# %% [markdown]
# # **Removing the Outliers:-**

# %%
continuous = df.drop()

# %%
for col in continuous:
upper_lim = df_t[col].quantile(.80)
lower_lim = df_t[col].quantile(.20)
df_t.loc[(df_t[col] > upper_lim),col] = upper_lim
df_t.loc[(df_t[col] < lower_lim),col] = lower_lim

# %% [markdown]
# # **Train and Test Split of the Dataset:-**

# %%
df2 = df.iloc[:,:-2]

# %%
df2.head(2)
# Out:
#    Bankrupt?  ...   Interest Coverage Ratio (Interest expense to EBIT)
# 0          1  ...                                           0.564050
# 1          1  ...                                           0.570175
#
# [2 rows x 94 columns]

# %%
df3 = df.iloc[:,1:]
df3.head(2)
# Out:
#     ROA(C) before interest and depreciation before interest  ...   Equity to Liability
# 0                                           0.370594         ...              0.016469
# 1                                           0.464291         ...              0.020794
#
# [2 rows x 95 columns]

# %%
X = df2
Y = df['Bankrupt?'].map({0:1,1:-1})

# %%
from scipy.stats import zscore

# We are transforming features (X)
X_  = X.apply(zscore)
X_.head()
# Out:
#    Bankrupt?  ...   Interest Coverage Ratio (Interest expense to EBIT)
# 0   5.476811  ...                                          -0.098978
# 1   5.476811  ...                                           0.364559
# 2   5.476811  ...                                          -0.125015
# 3   5.476811  ...                                          -0.052562
# 4   5.476811  ...                                           0.776395
#
# [5 rows x 94 columns]

# %%
X_.isnull().value_counts()
# Out:
# Bankrupt?   ROA(C) before interest and depreciation before interest   ROA(A) before interest and % after tax   ROA(B) before interest and depreciation after tax   Operating Gross Margin   Realized Sales Gross Margin   Operating Profit Rate   Pre-tax net Interest Rate   After-tax net Interest Rate   Non-industry income and expenditure/revenue   Continuous interest rate (after tax)   Operating Expense Rate   Research and development expense rate   Cash flow rate   Interest-bearing debt interest rate   Tax rate (A)   Net Value Per Share (B)   Net Value Per Share (A)   Net Value Per Share (C)   Persistent EPS in the Last Four Seasons   Cash Flow Per Share   Revenue Per Share (Yuan ¥)   Operating Profit Per Share (Yuan ¥)   Per Share Net profit before tax (Yuan ¥)   Realized Sales Gross Profit Growth Rate   Operating Profit Growth Rate   After-tax Net Profit Growth Rate   Regular Net Profit Growth Rate   Continuous Net Profit Growth Rate   Total Asset Growth Rate   Net Value Growth Rate  
# ...

# %%
from sklearn.model_selection import train_test_split
train_X,test_X,train_Y,test_Y = train_test_split(X_,Y,test_size=0.25, random_state=0, stratify=Y)

# %%
train_X.shape, test_X.shape
# Out:
# ((5114, 94), (1705, 94))

# %%
train_Y.shape, test_Y.shape
# Out:
# ((5114,), (1705,))

# %%
test_Y.value_counts()
# Out:
#  1    1650
# -1      55
# Name: Bankrupt?, dtype: int64

# %%
train_Y.value_counts()
# Out:
#  1    4949
# -1     165
# Name: Bankrupt?, dtype: int64

# %% [markdown]
# # **Building Isolation Forest Model:-**

# %%
from sklearn.ensemble import IsolationForest

# %%
clf=IsolationForest(n_estimators=100, max_samples='auto', \
                        max_features=1.0, bootstrap=True, n_jobs=-1, random_state=0, verbose=0, contamination=0.03)
clf.fit(train_X,train_Y)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=True, contamination=0.03,
#                 max_features=1.0, max_samples='auto', n_estimators=100,
#                 n_jobs=-1, random_state=0, verbose=0, warm_start=False)

# %%
pred_train = clf.predict(train_X)

# %%
np.unique(pred_train, return_counts=True)
# Out:
# (array([-1,  1]), array([ 154, 4960]))

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %%
print(classification_report(train_Y, pred_train))
print ("AUC: ", "{:.1%}".format(roc_auc_score(train_Y, pred_train)))
cm = confusion_matrix(train_Y, pred_train)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.25      0.24      0.24       165
#            1       0.97      0.98      0.98      4949
#
#     accuracy                           0.95      5114
#    macro avg       0.61      0.61      0.61      5114
# weighted avg       0.95      0.95      0.95      5114
#
# AUC:  60.7%

# %%
# confusion_matrix([0, 1, 0, 1], [1, 1, 1, 0]).ravel()
# >>> (tn, fp, fn, tp)

# %%
ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax) #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels', fontsize=20)
ax.set_ylabel('True labels',fontsize=20)
ax.set_title('Confusion Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print(cm)
# Out:
# [[  39  126]
#  [ 115 4834]]

# %%
pred_test = clf.predict(test_X)

# %%
print(classification_report(test_Y, pred_test))
print ("AUC: ", "{:.1%}".format(roc_auc_score(test_Y, pred_test)))
cm2 = confusion_matrix(test_Y, pred_test)
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.36      0.45      0.40        55
#            1       0.98      0.97      0.98      1650
#
#     accuracy                           0.96      1705
#    macro avg       0.67      0.71      0.69      1705
# weighted avg       0.96      0.96      0.96      1705
#
# AUC:  71.4%

# %%
# confusion_matrix([0, 1, 0, 1], [1, 1, 1, 0]).ravel()
# >>> (tn, fp, fn, tp)

# %%
ax= plt.subplot()
sns.heatmap(cm2, annot=True, ax = ax) #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels', fontsize=20)
ax.set_ylabel('True labels',fontsize=20)
ax.set_title('Confusion Matrix', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
print(cm2)
# Out:
# [[  25   30]
#  [  45 1605]]

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
df[df['Bankrupt?']==1]
# Out:
#       Bankrupt?  ...  anomaly
# 0             1  ...        1
# 1             1  ...        1
# 2             1  ...        1
# 3             1  ...        1
# 4             1  ...        1
# ...         ...  ...      ...
# 6591          1  ...        1
# 6640          1  ...       -1
# 6641          1  ...        1
# 6642          1  ...        1
# 6728          1  ...        1
#
# [220 rows x 97 columns]

# %%
bankrupt_index = df[df['Bankrupt?']==1].index

# %%
bankrupt_index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    5,   29,   30,   54,   55,
#             ...
#             6454, 6498, 6499, 6500, 6545, 6591, 6640, 6641, 6642, 6728],
#            dtype='int64', length=220)

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
pca.fit(metrics_df[to_model_columns])


res=pd.DataFrame(pca.transform(df[to_model_columns]))

Z = np.array(res)
figsize=(12, 7)
plt.figure(figsize=figsize)
plt.title("IsolationForest")
plt.contourf( Z, cmap=plt.cm.Blues_r)

b1 = plt.scatter(res[0], res[1], c='blue',
                 s=40,label="normal points")

b1 = plt.scatter(res.iloc[bankrupt_index,0],res.iloc[bankrupt_index,1], c='red',
                 s=40,  edgecolor="red",label="Actual outliers")
plt.legend(loc="upper right")
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
pca = PCA(n_components=3)  # Reduce to k=3 dimensions
scaler = StandardScaler()
#normalize the metrics
X = scaler.fit_transform(df[to_model_columns])
X_reduce = pca.fit_transform(X)

fig = plt.figure( figsize=(20,16))
ax = fig.add_subplot(111, projection='3d')
ax.set_zlabel("x_composite_3")

# Plot the compressed data points
ax.scatter(X_reduce[:, 0], X_reduce[:, 1], zs=X_reduce[:, 2], s=4, lw=1, label="inliers",c="blue")

# Plot x's for the ground truth outliers
ax.scatter(X_reduce[bankrupt_index,0],X_reduce[bankrupt_index,1], X_reduce[bankrupt_index,2],
           lw=2, s=60, marker="x", c="red", label="outliers")
ax.legend()
plt.show()

# %%
metrics_df[(metrics_df['anomaly']==-1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...  anomaly
# 56            1  ...       -1
# 379           1  ...       -1
# 427           1  ...       -1
# 1443          1  ...       -1
# 1861          1  ...       -1
# 1865          1  ...       -1
# 1870          1  ...       -1
# 1951          1  ...       -1
# 2001          1  ...       -1
# 2004          1  ...       -1
# 2099          1  ...       -1
# 2295          1  ...       -1
# 2344          1  ...       -1
# 2440          1  ...       -1
# 2470          1  ...       -1
# 2496          1  ...       -1
# 2640          1  ...       -1
# 6640          1  ...       -1
#
# [18 rows x 97 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(2)
pca.fit(metrics_df[to_model_columns])


res=pd.DataFrame(pca.transform(metrics_df[to_model_columns]))

Z = np.array(res)
figsize=(12, 7)
plt.figure(figsize=figsize)
plt.title("IsolationForest")
plt.contourf( Z, cmap=plt.cm.Blues_r)

b1 = plt.scatter(res[0], res[1], c='blue',
                 s=40,label="normal points")

b1 = plt.scatter(res.iloc[outlier_index,0],res.iloc[outlier_index,1], c='red',
                 s=40,  edgecolor="red",label="predicted outliers")
plt.legend(loc="upper right")
plt.show()

# %%
from sklearn.ensemble import IsolationForest
clf=IsolationForest(n_estimators=100, max_samples='auto', \
                        max_features=1.0, bootstrap=True, n_jobs=-1, random_state=0, verbose=0, contamination=0.03)
clf.fit(metrics_df[to_model_columns])
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=True, contamination=0.03,
#                 max_features=1.0, max_samples='auto', n_estimators=100,
#                 n_jobs=-1, random_state=0, verbose=0, warm_start=False)

# %%
pred = clf.predict(metrics_df[to_model_columns])
metrics_df['anomaly']=pred
outliers=metrics_df.loc[metrics_df['anomaly']==-1]
outlier_index=list(outliers.index)
#print(outlier_index)
#Find the number of anomalies and normal points here points classified -1 are anomalous
print(metrics_df['anomaly'].value_counts())
# Out:
#  1    6614
# -1     205
# Name: anomaly, dtype: int64

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
metrics_df[(metrics_df['anomaly']==-1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...  anomaly
# 56            1  ...       -1
# 379           1  ...       -1
# 427           1  ...       -1
# 1443          1  ...       -1
# 1751          1  ...       -1
# 1753          1  ...       -1
# 1755          1  ...       -1
# 1861          1  ...       -1
# 1865          1  ...       -1
# 1869          1  ...       -1
# 1870          1  ...       -1
# 1949          1  ...       -1
# 1951          1  ...       -1
# 2001          1  ...       -1
# 2004          1  ...       -1
# 2099          1  ...       -1
# 2147          1  ...       -1
# 2198          1  ...       -1
# 2295          1  ...       -1
# 2344          1  ...       -1
# 2440          1  ...       -1
# 2470          1  ...       -1
# 2496          1  ...       -1
# 2523          1  ...       -1
# 2640          1  ...       -1
# 3016          1  ...       -1
# 3595          1  ...       -1
# 3597          1  ...       -1
# 3908          1  ...       -1
# 4918          1  ...       -1
# ...

# %%
from sklearn.covariance import EllipticEnvelope
from sklearn.neighbors import LocalOutlierFactor

# %%
clf2=EllipticEnvelope(contamination=0.03, random_state=0)
clf2.fit(metrics_df[to_model_columns])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/covariance/_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# EllipticEnvelope(assume_centered=False, contamination=0.03, random_state=0,
#                  store_precision=True, support_fraction=None)

# %%
pred = clf2.predict(metrics_df[to_model_columns])
metrics_df['anomaly2']=pred
outliers2=metrics_df.loc[metrics_df['anomaly2']==-1]
outlier_index2=list(outliers.index)
#print(outlier_index)
#Find the number of anomalies and normal points here points classified -1 are anomalous
print(metrics_df['anomaly2'].value_counts())
# Out:
#  1    6614
# -1     205
# Name: anomaly2, dtype: int64

# %%
metrics_df[(metrics_df['anomaly']==-1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...  anomaly2
# 56            1  ...         1
# 379           1  ...         1
# 427           1  ...         1
# 1443          1  ...         1
# 1751          1  ...         1
# 1753          1  ...         1
# 1755          1  ...         1
# 1861          1  ...         1
# 1865          1  ...         1
# 1869          1  ...         1
# 1870          1  ...         1
# 1949          1  ...        -1
# 1951          1  ...         1
# 2001          1  ...         1
# 2004          1  ...         1
# 2099          1  ...         1
# 2147          1  ...         1
# 2198          1  ...         1
# 2295          1  ...         1
# 2344          1  ...         1
# 2440          1  ...         1
# 2470          1  ...         1
# 2496          1  ...         1
# 2523          1  ...         1
# 2640          1  ...         1
# 3016          1  ...         1
# 3595          1  ...         1
# 3597          1  ...         1
# 3908          1  ...         1
# ...

# %%
clf3 = LocalOutlierFactor(n_neighbors=35, contamination=0.03, novelty=True)
clf3.fit(metrics_df[to_model_columns])
# Out:
# LocalOutlierFactor(algorithm='auto', contamination=0.03, leaf_size=30,
#                    metric='minkowski', metric_params=None, n_jobs=None,
#                    n_neighbors=35, novelty=True, p=2)

# %%
pred = clf3.predict(metrics_df[to_model_columns])
metrics_df['anomaly3']=pred
outliers3=metrics_df.loc[metrics_df['anomaly3']==-1]
outlier_index3=list(outliers.index)
#print(outlier_index)
#Find the number of anomalies and normal points here points classified -1 are anomalous
print(metrics_df['anomaly3'].value_counts())
# Out:
#  1    6622
# -1     197
# Name: anomaly3, dtype: int64

# %%
metrics_df[(metrics_df['anomaly3']==-1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...  anomaly3
# 236           1  ...        -1
# 284           1  ...        -1
# 379           1  ...        -1
# 1861          1  ...        -1
# 2001          1  ...        -1
# 2045          1  ...        -1
# 2147          1  ...        -1
# 2197          1  ...        -1
# 2344          1  ...        -1
# 2496          1  ...        -1
# 6545          1  ...        -1
#
# [11 rows x 99 columns]

# %%
from sklearn.svm import OneClassSVM

# %%
clf4 = OneClassSVM(kernel='rbf', nu=0.03)
clf4.fit(metrics_df[to_model_columns])
# Out:
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma='scale', kernel='rbf',
#             max_iter=-1, nu=0.03, shrinking=True, tol=0.001, verbose=False)

# %%
pred = clf4.predict(metrics_df[to_model_columns])
metrics_df['anomaly4']=pred
outliers4=metrics_df.loc[metrics_df['anomaly4']==-1]
outlier_index4=list(outliers.index)
#print(outlier_index)
#Find the number of anomalies and normal points here points classified -1 are anomalous
print(metrics_df['anomaly4'].value_counts())
# Out:
#  1    6614
# -1     205
# Name: anomaly4, dtype: int64

# %%
metrics_df[(metrics_df['anomaly4']==-1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...  anomaly4
# 158           1  ...        -1
# 236           1  ...        -1
# 1442          1  ...        -1
# 2147          1  ...        -1
# 2344          1  ...        -1
# 2470          1  ...        -1
# 2523          1  ...        -1
# 2771          1  ...        -1
# 5228          1  ...        -1
#
# [9 rows x 100 columns]

# %%
def correlation(df,threshold):
  col_corr=set()
  corr_matrix= df.corr()
  for i in range (len(corr_matrix.columns)):
    for j in range(i):
      if abs (corr_matrix.iloc[i,j])>threshold:
        colname=corr_matrix.columns[i]
        col_corr.add(colname)
  return col_corr

# %%
correlation(df,0.7)
# Out:
# {' After-tax net Interest Rate',
#  ' CFO to Assets',
#  ' Cash Flow to Liability',
#  ' Cash Flow to Sales',
#  ' Continuous interest rate (after tax)',
#  ' Current Assets/Total Assets',
#  ' Current Liabilities/Equity',
#  ' Current Liability to Assets',
#  ' Current Liability to Equity',
#  ' Current Liability to Liability',
#  ' Equity to Long-term Liability',
#  ' Gross Profit to Sales',
#  ' Inventory and accounts receivable/Net value',
#  ' Liability to Equity',
#  " Net Income to Stockholder's Equity",
#  ' Net Income to Total Assets',
#  ' Net Value Per Share (A)',
#  ' Net Value Per Share (C)',
#  ' Net Worth Turnover Rate (times)',
#  ' Net profit before tax/Paid-in capital',
#  ' Net worth/Assets',
#  ' Operating Funds to Liability',
#  ' Operating Profit Per Share (Yuan ¥)',
#  ' Operating profit/Paid-in capital',
#  ' Per Share Net profit before tax (Yuan ¥)',
#  ' Persistent EPS in the Last Four Seasons',
#  ' Pre-tax net Interest Rate',
# ...

# %%
list(correlation(df,0.7))
# Out:
# [' Cash Flow to Liability',
#  ' Working Capital/Equity',
#  ' Realized Sales Gross Margin',
#  ' After-tax net Interest Rate',
#  ' Current Liabilities/Equity',
#  ' Pre-tax net Interest Rate',
#  ' Operating profit/Paid-in capital',
#  ' Operating Profit Per Share (Yuan ¥)',
#  ' ROA(B) before interest and depreciation after tax',
#  ' Current Liability to Assets',
#  ' Liability to Equity',
#  ' Current Assets/Total Assets',
#  ' Net Value Per Share (C)',
#  ' Continuous interest rate (after tax)',
#  ' Net Value Per Share (A)',
#  ' Operating Funds to Liability',
#  ' Current Liability to Equity',
#  ' Current Liability to Liability',
#  ' Net Income to Total Assets',
#  ' Cash Flow to Sales',
#  " Net Income to Stockholder's Equity",
#  ' Equity to Long-term Liability',
#  ' ROA(A) before interest and % after tax',
#  ' Net profit before tax/Paid-in capital',
#  ' Gross Profit to Sales',
#  ' Net Worth Turnover Rate (times)',
#  ' Working capitcal Turnover Rate',
# ...

# %%
to_model_columns2 = [' Cash Flow to Liability', ' Working Capital/Equity',' Realized Sales Gross Margin',' After-tax net Interest Rate',' Current Liabilities/Equity',\
' Pre-tax net Interest Rate',\
' Operating profit/Paid-in capital',\
' Operating Profit Per Share (Yuan ¥)',\
' ROA(B) before interest and depreciation after tax',\
' Current Liability to Assets',
' Liability to Equity',
' Current Assets/Total Assets',
' Net Value Per Share (C)',
' Continuous interest rate (after tax)',
' Net Value Per Share (A)',
' Operating Funds to Liability',
' Current Liability to Equity',
' Current Liability to Liability',
 ' Net Income to Total Assets',
 ' Cash Flow to Sales',
 " Net Income to Stockholder's Equity",
 ' Equity to Long-term Liability',
 ' ROA(A) before interest and % after tax',
 ' Net profit before tax/Paid-in capital',
 ' Gross Profit to Sales',
 ' Net Worth Turnover Rate (times)',
 ' Working capitcal Turnover Rate',
 ' Regular Net Profit Growth Rate',
 ' Persistent EPS in the Last Four Seasons',
 ' Retained Earnings to Total Assets',
 ' Per Share Net profit before tax (Yuan ¥)',
 ' Net worth/Assets',
 ' Inventory and accounts receivable/Net value',
 ' CFO to Assets']

# %%
from sklearn.ensemble import IsolationForest
clf5=IsolationForest(n_estimators=100, max_samples='auto', \
                        max_features=1.0, bootstrap=False, n_jobs=-1, random_state=0, verbose=0, contamination=0.03)
clf5.fit(metrics_df[to_model_columns2])
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=0.03,
#                 max_features=1.0, max_samples='auto', n_estimators=100,
#                 n_jobs=-1, random_state=0, verbose=0, warm_start=False)

# %%
pred = clf5.predict(metrics_df[to_model_columns2])
metrics_df['anomaly5']=pred
outliers5=metrics_df.loc[metrics_df['anomaly5']==-1]
outlier_index=list(outliers5.index)
#print(outlier_index)
#Find the number of anomalies and normal points here points classified -1 are anomalous
print(metrics_df['anomaly5'].value_counts())
# Out:
#  1    6614
# -1     205
# Name: anomaly5, dtype: int64

# %%
df['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
metrics_df[(metrics_df['anomaly5']==-1) & (metrics_df['Bankrupt?']== 1)]
# Out:
#       Bankrupt?  ...  anomaly5
# 56            1  ...        -1
# 379           1  ...        -1
# 427           1  ...        -1
# 576           1  ...        -1
# 1026          1  ...        -1
# 1443          1  ...        -1
# 1640          1  ...        -1
# 1751          1  ...        -1
# 1753          1  ...        -1
# 1755          1  ...        -1
# 1861          1  ...        -1
# 1865          1  ...        -1
# 1869          1  ...        -1
# 1870          1  ...        -1
# 1948          1  ...        -1
# 1949          1  ...        -1
# 1951          1  ...        -1
# 2000          1  ...        -1
# 2001          1  ...        -1
# 2004          1  ...        -1
# 2099          1  ...        -1
# 2147          1  ...        -1
# 2198          1  ...        -1
# 2293          1  ...        -1
# 2295          1  ...        -1
# 2440          1  ...        -1
# 2470          1  ...        -1
# 2496          1  ...        -1
# 2640          1  ...        -1
# ...

# %%
def fisher_feature(df,x,y):
  from skfeature.function.similarity_based import fisher_score
  import matplotlib.pyplot as plt
  # %matplotlib inline
  # Calculating Scores
  ranks= fisher_score.fisher_score(x,y)
  #plotting the ranks
  feat_importances= pd.Series(ranks,df.columns[0:len(df.columns)-1])
  feat_importances.plot(kind='barh', color='teal')
  plt.show()

# %%
# Out:
#   File "<ipython-input-238-12646b2ba99c>", line 1
#     y = df[~in df['Bankrupt?']]
#              ^
# SyntaxError: invalid syntax

# %%
fisher_feature(df,df.drop(['Bankrupt?']),df['Bankrupt?'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-9a17a4b89ef1> in <module>()
# ----> 1 fisher_feature(df,df.drop(['Bankrupt?']),df['Bankrupt?'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...
